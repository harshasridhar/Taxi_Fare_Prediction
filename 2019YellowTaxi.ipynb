# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('yellow_tripdata_2019-01.csv')

# %%
df1.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-01-01 00:46:40   2019-01-01 00:53:20                1
# 1         1  2019-01-01 00:59:47   2019-01-01 01:18:59                1
# 2         2  2018-12-21 13:48:30   2018-12-21 13:52:40                3
# 3         2  2018-11-28 15:52:25   2018-11-28 15:55:45                5
# 4         2  2018-11-28 15:56:57   2018-11-28 15:58:33                5
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            1.5           1                  N           151           239
# 1            2.6           1                  N           239           246
# 2            0.0           1                  N           236           236
# 3            0.0           1                  N           193           193
# 4            0.0           2                  N           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df1.isnull().sum()
# Out:
# VendorID                       0
# tpep_pickup_datetime           0
# tpep_dropoff_datetime          0
# passenger_count                0
# trip_distance                  0
# RatecodeID                     0
# store_and_fwd_flag             0
# PULocationID                   0
# DOLocationID                   0
# payment_type                   0
# fare_amount                    0
# extra                          0
# mta_tax                        0
# tip_amount                     0
# tolls_amount                   0
# improvement_surcharge          0
# total_amount                   0
# congestion_surcharge     4855978
# dtype: int64

# %%
df1.describe().T
# Out:
#                            count        mean         std    min     25%  \
# VendorID               7667792.0    1.636775    0.539820    1.0    1.00
# passenger_count        7667792.0    1.567078    1.224431    0.0    1.00
# trip_distance          7667792.0    2.801084    3.737529    0.0    0.90
# RatecodeID             7667792.0    1.058371    0.678089    1.0    1.00
# PULocationID           7667792.0  165.500918   66.391800    1.0  130.00
# DOLocationID           7667792.0  163.752906   70.364452    1.0  113.00
# payment_type           7667792.0    1.291776    0.473323    1.0    1.00
# fare_amount            7667792.0   12.409409  262.072058 -362.0    6.00
# extra                  7667792.0    0.328039    0.507479  -60.0    0.00
# mta_tax                7667792.0    0.496846    0.053378   -0.5    0.50
# tip_amount             7667792.0    1.827367    2.501213  -63.5    0.00
# tolls_amount           7667792.0    0.316919    2.023665  -70.0    0.00
# ...

# %%
df1.dropna(subset = ["congestion_surcharge"],inplace= True)

# %%
df1.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df1 = df1[df1.fare_amount>=0]
df1 = df1[df1.extra>=0]
df1 = df1[df1.mta_tax>=0]
df1 = df1[df1.tip_amount>=0]
df1 = df1[df1.tolls_amount>=0]
df1 = df1[df1.improvement_surcharge>=0]
df1 = df1[df1.total_amount>=0]

# %%
df1.describe().T
# Out:
#                            count        mean         std  min    25%     50%  \
# VendorID               2809183.0    1.621300    0.504326  1.0    1.0    2.00
# passenger_count        2809183.0    1.553324    1.218611  0.0    1.0    1.00
# trip_distance          2809183.0    2.757349    3.704488  0.0    0.9    1.50
# RatecodeID             2809183.0    1.056254    0.644536  1.0    1.0    1.00
# PULocationID           2809183.0  166.277770   66.085431  1.0  132.0  162.00
# DOLocationID           2809183.0  164.546435   70.050569  1.0  113.0  162.00
# payment_type           2809183.0    1.273010    0.460668  1.0    1.0    1.00
# fare_amount            2809183.0   12.402967  212.493224  0.0    6.0    9.00
# extra                  2809183.0    0.336887    0.567669  0.0    0.0    0.00
# mta_tax                2809183.0    0.497796    0.033134  0.0    0.5    0.50
# tip_amount             2809183.0    1.882497    2.484214  0.0    0.0    1.46
# ...

# %%
df2 = pd.read_csv('yellow_tripdata_2019-02.csv')
df3 = pd.read_csv('yellow_tripdata_2019-03.csv')
df4 = pd.read_csv('yellow_tripdata_2019-04.csv')

# %%
df2.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-02-01 00:59:04   2019-02-01 01:07:27                1
# 1         1  2019-02-01 00:33:09   2019-02-01 01:03:58                1
# 2         1  2019-02-01 00:09:03   2019-02-01 00:09:16                1
# 3         1  2019-02-01 00:45:38   2019-02-01 00:51:10                1
# 4         1  2019-02-01 00:25:30   2019-02-01 00:28:14                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            2.1           1                  N            48           234
# 1            9.8           1                  N           230            93
# 2            0.0           1                  N           145           145
# 3            0.8           1                  N            95            95
# 4            0.8           1                  N           140           263
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df2.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df2.describe().T
# Out:
#                            count        mean         std     min     25%  \
# VendorID               7019375.0    1.636639    0.524861    1.00    1.00
# passenger_count        7019375.0    1.571420    1.228251    0.00    1.00
# trip_distance          7019375.0    2.884923    3.780133    0.00    0.94
# RatecodeID             7019375.0    1.061126    0.637502    1.00    1.00
# PULocationID           7019375.0  163.509255   65.943774    1.00  114.00
# DOLocationID           7019375.0  161.803245   70.078660    1.00  112.00
# payment_type           7019375.0    1.269927    0.466612    1.00    1.00
# fare_amount            7019375.0   12.746706  255.914870 -400.00    6.50
# extra                  7019375.0    1.157935    1.268855   -4.50    0.00
# mta_tax                7019375.0    0.495960    0.052404   -0.50    0.50
# tip_amount             7019375.0    2.163211    2.634801  -62.00    0.00
# tolls_amount           7019375.0    0.341730    1.673112  -26.26    0.00
# ...

# %%
df2 = df2[df2.fare_amount>=0]
df2 = df2[df2.extra>=0]
df2 = df2[df2.mta_tax>=0]
df2 = df2[df2.tip_amount>=0]
df2 = df2[df2.tolls_amount>=0]
df2 = df2[df2.improvement_surcharge>=0]
df2 = df2[df2.total_amount>=0]

# %%
df2.describe().T
# Out:
#                            count        mean         std  min     25%     50%  \
# VendorID               7009559.0    1.636131    0.525052  1.0    1.00    2.00
# passenger_count        7009559.0    1.571361    1.228252  0.0    1.00    1.00
# trip_distance          7009559.0    2.887618    3.780927  0.0    0.94    1.60
# RatecodeID             7009559.0    1.060697    0.621949  1.0    1.00    1.00
# PULocationID           7009559.0  163.512367   65.938385  1.0  114.00  162.00
# DOLocationID           7009559.0  161.810364   70.078786  1.0  112.00  162.00
# payment_type           7009559.0    1.267117    0.460254  1.0    1.00    1.00
# fare_amount            7009559.0   12.776010  256.092098  0.0    6.50    9.00
# extra                  7009559.0    1.160113    1.268215  0.0    0.00    0.50
# mta_tax                7009559.0    0.497284    0.037951  0.0    0.50    0.50
# tip_amount             7009559.0    2.166237    2.635004  0.0    0.00    1.86
# ...

# %%
df3.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-03-01 00:24:41   2019-03-01 00:25:31                1
# 1         1  2019-03-01 00:25:27   2019-03-01 00:36:37                2
# 2         1  2019-03-01 00:05:21   2019-03-01 00:38:23                1
# 3         1  2019-03-01 00:48:55   2019-03-01 01:06:03                1
# 4         1  2019-03-01 00:11:42   2019-03-01 00:16:40                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0           1                  N           145           145
# 1            3.7           1                  N            95           130
# 2           14.1           1                  N           249            28
# 3            9.6           1                  N           138            98
# 4            0.8           1                  N            48            48
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df3.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df3.describe().T
# Out:
#                            count        mean         std     min     25%  \
# VendorID               7832545.0    1.636294    0.513368    1.00    1.00
# passenger_count        7832545.0    1.575179    1.228348    0.00    1.00
# trip_distance          7832545.0    2.991058    3.890174    0.00    0.97
# RatecodeID             7832545.0    1.066853    0.698237    1.00    1.00
# PULocationID           7832545.0  161.991992   65.875394    1.00  114.00
# DOLocationID           7832545.0  160.275596   70.236284    1.00  107.00
# payment_type           7832545.0    1.278309    0.471327    1.00    1.00
# fare_amount            7832545.0   13.179200  346.829122 -447.00    6.50
# extra                  7832545.0    1.203193    1.284208  -57.50    0.00
# mta_tax                7832545.0    0.495539    0.069060   -0.50    0.50
# tip_amount             7832545.0    2.231696   50.630924  -89.89    0.00
# tolls_amount           7832545.0    0.364951    1.677116  -25.00    0.00
# ...

# %%
df3 = df3[df3.fare_amount>=0]
df3 = df3[df3.extra>=0]
df3 = df3[df3.mta_tax>=0]
df3 = df3[df3.tip_amount>=0]
df3 = df3[df3.tolls_amount>=0]
df3 = df3[df3.improvement_surcharge>=0]
df3 = df3[df3.total_amount>=0]
df3.describe().T
# Out:
#                            count        mean         std  min     25%     50%  \
# VendorID               7820495.0    1.635734    0.513565  1.0    1.00    2.00
# passenger_count        7820495.0    1.575114    1.228352  0.0    1.00    1.00
# trip_distance          7820495.0    2.994122    3.891183  0.0    0.98    1.62
# RatecodeID             7820495.0    1.066583    0.692850  1.0    1.00    1.00
# PULocationID           7820495.0  161.996154   65.870877  1.0  114.00  161.00
# DOLocationID           7820495.0  160.272769   70.234801  1.0  107.00  162.00
# payment_type           7820495.0    1.275188    0.464279  1.0    1.00    1.00
# fare_amount            7820495.0   13.213410  347.094500  0.0    6.50    9.50
# extra                  7820495.0    1.205662    1.283084  0.0    0.00    0.50
# mta_tax                7820495.0    0.497000    0.047633  0.0    0.50    0.50
# tip_amount             7820495.0    2.235180   50.669783  0.0    0.00    1.95
# ...

# %%
df4.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-04-01 00:04:09   2019-04-01 00:06:35                1
# 1         1  2019-04-01 00:22:45   2019-04-01 00:25:43                1
# 2         1  2019-04-01 00:39:48   2019-04-01 01:19:39                1
# 3         1  2019-04-01 00:35:32   2019-04-01 00:37:11                1
# 4         1  2019-04-01 00:44:05   2019-04-01 00:57:58                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.5           1                  N           239           239
# 1            0.7           1                  N           230           100
# 2           10.9           1                  N            68           127
# 3            0.2           1                  N            68            68
# 4            4.8           1                  N            50            42
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df4.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df4.describe().T
# Out:
#                            count        mean         std     min    25%  \
# VendorID               7433139.0    1.636259    0.507108    1.00    1.0
# passenger_count        7433139.0    1.573301    1.224597    0.00    1.0
# trip_distance          7433139.0    2.998019    3.908213    0.00    1.0
# RatecodeID             7433139.0    1.057416    0.703754    1.00    1.0
# PULocationID           7433139.0  163.367204   66.156637    1.00  116.0
# DOLocationID           7433139.0  161.534559   70.379452    1.00  107.0
# payment_type           7433139.0    1.288608    0.476180    1.00    1.0
# fare_amount            7433139.0   13.194330  145.719873 -450.08    6.5
# extra                  7433139.0    1.212602    1.288626  -24.60    0.0
# mta_tax                7433139.0    0.495736    0.054829   -0.50    0.5
# tip_amount             7433139.0    2.212688    2.772410  -88.00    0.0
# tolls_amount           7433139.0    0.382120    1.718031  -23.00    0.0
# ...

# %%
df4 = df4[df4.fare_amount>=0]
df4 = df4[df4.extra>=0]
df4 = df4[df4.mta_tax>=0]
df4 = df4[df4.tip_amount>=0]
df4 = df4[df4.tolls_amount>=0]
df4 = df4[df4.improvement_surcharge>=0]
df4 = df4[df4.total_amount>=0]
df4.describe().T
# Out:
#                            count        mean         std  min    25%     50%  \
# VendorID               7421225.0    1.635676    0.507305  1.0    1.0    2.00
# passenger_count        7421225.0    1.573194    1.224555  0.0    1.0    1.00
# trip_distance          7421225.0    3.001184    3.909175  0.0    1.0    1.65
# RatecodeID             7421225.0    1.057185    0.703663  1.0    1.0    1.00
# PULocationID           7421225.0  163.371359   66.152273  1.0  116.0  162.00
# DOLocationID           7421225.0  161.530847   70.376616  1.0  107.0  162.00
# payment_type           7421225.0    1.285346    0.468926  1.0    1.0    1.00
# fare_amount            7421225.0   13.231540  145.832083  0.0    6.5    9.50
# extra                  7421225.0    1.215162    1.287825  0.0    0.0    0.50
# mta_tax                7421225.0    0.497309    0.036752  0.0    0.5    0.50
# tip_amount             7421225.0    2.216272    2.772509  0.0    0.0    1.95
# ...

# %%
df5 = pd.read_csv('yellow_tripdata_2019-05.csv')
df6 = pd.read_csv('yellow_tripdata_2019-06.csv')
df7 = pd.read_csv('yellow_tripdata_2019-07.csv')
df8 = pd.read_csv('yellow_tripdata_2019-08.csv')
# Out:
# C:\Users\KritiBhardwaj\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df5.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-05-01 00:14:50   2019-05-01 00:16:48                1
# 1         1  2019-05-01 00:35:54   2019-05-01 00:37:27                1
# 2         1  2019-05-01 00:37:45   2019-05-01 00:37:49                1
# 3         1  2019-05-01 00:44:57   2019-05-01 00:50:11                1
# 4         1  2019-05-01 00:59:48   2019-05-01 01:10:22                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0           1                  N           145           145
# 1            1.5           1                  N           145           145
# 2            1.5           1                  N           145           145
# 3            0.7           1                  N           161           161
# 4            2.0           1                  N           163           141
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df5.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df5.describe().T
# Out:
#                            count        mean        std    min    25%     50%  \
# VendorID               7565261.0    1.640188   0.502813    1.0    1.0    2.00
# passenger_count        7565261.0    1.569429   1.220021    0.0    1.0    1.00
# trip_distance          7565261.0    3.032936   3.944314    0.0    1.0    1.65
# RatecodeID             7565261.0    1.055399   0.683969    1.0    1.0    1.00
# PULocationID           7565261.0  163.396135  66.179834    1.0  125.0  162.00
# DOLocationID           7565261.0  161.817161  70.252175    1.0  113.0  162.00
# payment_type           7565261.0    1.288196   0.477429    1.0    1.0    1.00
# fare_amount            7565261.0   13.443221  12.548973 -375.0    6.5    9.50
# extra                  7565261.0    1.187887   1.282190   -5.5    0.0    0.50
# mta_tax                7565261.0    0.495463   0.056024   -0.5    0.5    0.50
# tip_amount             7565261.0    2.258855   2.837838  -82.6    0.0    1.95
# ...

# %%
df5 = df5[df5.fare_amount>=0]
df5 = df5[df5.extra>=0]
df5 = df5[df5.mta_tax>=0]
df5 = df5[df5.tip_amount>=0]
df5 = df5[df5.tolls_amount>=0]
df5 = df5[df5.improvement_surcharge>=0]
df5 = df5[df5.total_amount>=0]
df5.describe().T
# Out:
#                            count        mean        std  min    25%     50%  \
# VendorID               7551589.0    1.639537   0.503034  1.0    1.0    2.00
# passenger_count        7551589.0    1.569370   1.220051  0.0    1.0    1.00
# trip_distance          7551589.0    3.036361   3.945143  0.0    1.0    1.66
# RatecodeID             7551589.0    1.055089   0.683834  1.0    1.0    1.00
# PULocationID           7551589.0  163.401439  66.176217  1.0  125.0  162.00
# DOLocationID           7551589.0  161.813562  70.250180  1.0  113.0  162.00
# payment_type           7551589.0    1.284562   0.469394  1.0    1.0    1.00
# fare_amount            7551589.0   13.489308  12.486903  0.0    6.5    9.50
# extra                  7551589.0    1.190702   1.281341  0.0    0.0    0.50
# mta_tax                7551589.0    0.497241   0.037187  0.0    0.5    0.50
# tip_amount             7551589.0    2.263009   2.838184  0.0    0.0    1.95
# ...

# %%
df6.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-06-01 00:55:13   2019-06-01 00:56:17                1
# 1         1  2019-06-01 00:06:31   2019-06-01 00:06:52                1
# 2         1  2019-06-01 00:17:05   2019-06-01 00:36:38                1
# 3         1  2019-06-01 00:59:02   2019-06-01 00:59:12                0
# 4         1  2019-06-01 00:03:25   2019-06-01 00:15:42                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0           1                  N           145           145
# 1            0.0           1                  N           262           263
# 2            4.4           1                  N            74             7
# 3            0.8           1                  N           145           145
# 4            1.7           1                  N           113           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df6.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df6.describe().T
# Out:
#                            count        mean         std  min    25%     50%  \
# VendorID               6927014.0    1.641823    0.502123  1.0    1.0    2.00
# passenger_count        6927014.0    1.567293    1.210915  0.0    1.0    1.00
# trip_distance          6927014.0    3.082178   17.917852  0.0    1.0    1.69
# RatecodeID             6927014.0    1.059103    0.735053  1.0    1.0    1.00
# PULocationID           6927014.0  162.306433   66.380760  1.0  114.0  161.00
# DOLocationID           6927014.0  160.814256   70.462014  1.0  107.0  162.00
# payment_type           6927014.0    1.287958    0.471928  1.0    1.0    1.00
# fare_amount            6927014.0   13.715081  132.456228  0.0    6.5    9.50
# extra                  6927014.0    1.167732    1.274470  0.0    0.0    0.50
# mta_tax                6927014.0    0.496985    0.089937  0.0    0.5    0.50
# tip_amount             6927014.0    2.270616    2.962774  0.0    0.0    1.95
# ...

# %%
df6 = df6[df6.fare_amount>=0]
df6 = df6[df6.extra>=0]
df6 = df6[df6.mta_tax>=0]
df6 = df6[df6.tip_amount>=0]
df6 = df6[df6.tolls_amount>=0]
df6 = df6[df6.improvement_surcharge>=0]
df6 = df6[df6.total_amount>=0]
df6.describe().T
# Out:
#                            count        mean         std  min    25%     50%  \
# VendorID               6927014.0    1.641823    0.502123  1.0    1.0    2.00
# passenger_count        6927014.0    1.567293    1.210915  0.0    1.0    1.00
# trip_distance          6927014.0    3.082178   17.917852  0.0    1.0    1.69
# RatecodeID             6927014.0    1.059103    0.735053  1.0    1.0    1.00
# PULocationID           6927014.0  162.306433   66.380760  1.0  114.0  161.00
# DOLocationID           6927014.0  160.814256   70.462014  1.0  107.0  162.00
# payment_type           6927014.0    1.287958    0.471928  1.0    1.0    1.00
# fare_amount            6927014.0   13.715081  132.456228  0.0    6.5    9.50
# extra                  6927014.0    1.167732    1.274470  0.0    0.0    0.50
# mta_tax                6927014.0    0.496985    0.089937  0.0    0.5    0.50
# tip_amount             6927014.0    2.270616    2.962774  0.0    0.0    1.95
# ...

# %%
df7.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       2.0  2019-07-01 00:51:04   2019-07-01 00:51:33              1.0
# 1       2.0  2019-07-01 00:46:04   2019-07-01 01:05:46              1.0
# 2       1.0  2019-07-01 00:25:09   2019-07-01 01:00:56              1.0
# 3       2.0  2019-07-01 00:33:32   2019-07-01 01:15:27              1.0
# 4       1.0  2019-07-01 00:00:55   2019-07-01 00:13:05              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.00         1.0                  N           193           193
# 1           4.16         1.0                  N           234            25
# 2          18.80         2.0                  N           132            42
# 3          18.46         2.0                  N           132           142
# 4           1.70         1.0                  N           107           114
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df7.isnull().sum()
# Out:
# VendorID                 33959
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          33959
# trip_distance                0
# RatecodeID               33959
# store_and_fwd_flag       33959
# PULocationID                 0
# DOLocationID                 0
# payment_type             33959
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# dtype: int64

# %%
df7.dropna(subset = ["VendorID"],inplace= True)
df7.dropna(subset = ["passenger_count"],inplace= True)
df7.dropna(subset = ["RatecodeID"],inplace= True)
df7.dropna(subset = ["store_and_fwd_flag"],inplace= True)
df7.dropna(subset = ["payment_type"],inplace= True)

# %%
df7.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df7.describe().T
# Out:
#                            count        mean        std     min    25%  \
# VendorID               6276460.0    1.647390   0.488162    1.00    1.0
# passenger_count        6276460.0    1.572045   1.214311    0.00    1.0
# trip_distance          6276460.0    3.070979   4.021044    0.00    1.0
# RatecodeID             6276460.0    1.061235   0.749586    1.00    1.0
# PULocationID           6276460.0  161.781288  65.586465    1.00  114.0
# DOLocationID           6276460.0  159.942917  70.043242    1.00  107.0
# payment_type           6276460.0    1.305580   0.487784    1.00    1.0
# fare_amount            6276460.0   13.486902  13.005791 -450.00    6.5
# extra                  6276460.0    1.156179   1.273794   -7.00    0.0
# mta_tax                6276460.0    0.494774   0.060292   -0.50    0.5
# tip_amount             6276460.0    2.195290   2.878196 -221.00    0.0
# tolls_amount           6276460.0    0.395568   1.873907  -33.24    0.0
# ...

# %%
df7 = df7[df7.fare_amount>=0]
df7 = df7[df7.extra>=0]
df7 = df7[df7.mta_tax>=0]
df7 = df7[df7.tip_amount>=0]
df7 = df7[df7.tolls_amount>=0]
df7 = df7[df7.improvement_surcharge>=0]
df7 = df7[df7.total_amount>=0]
df7.describe().T
# Out:
#                            count        mean        std  min    25%     50%  \
# VendorID               6263184.0    1.646644   0.488408  1.0    1.0    2.00
# passenger_count        6263184.0    1.572036   1.214443  0.0    1.0    1.00
# trip_distance          6263184.0    3.074649   4.021884  0.0    1.0    1.67
# RatecodeID             6263184.0    1.060929   0.749652  1.0    1.0    1.00
# PULocationID           6263184.0  161.784551  65.582303  1.0  114.0  161.00
# DOLocationID           6263184.0  159.936703  70.040105  1.0  107.0  162.00
# payment_type           6263184.0    1.301337   0.478518  1.0    1.0    1.00
# fare_amount            6263184.0   13.541279  12.932865  0.0    6.5    9.50
# extra                  6263184.0    1.159433   1.272841  0.0    0.0    0.50
# mta_tax                6263184.0    0.496855   0.039676  0.0    0.5    0.50
# tip_amount             6263184.0    2.200021   2.877377  0.0    0.0    1.86
# ...

# %%
df8.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2019-08-01 00:09:46   2019-08-01 00:10:36              1.0
# 1       1.0  2019-08-01 00:30:47   2019-08-01 00:31:39              1.0
# 2       1.0  2019-08-01 00:44:50   2019-08-01 00:46:32              1.0
# 3       1.0  2019-08-01 00:57:16   2019-08-01 00:58:20              1.0
# 4       1.0  2019-08-01 00:59:18   2019-08-01 01:04:13              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N           145           145
# 1            0.0         1.0                  N           145           145
# 2            7.1         1.0                  N           145           145
# 3            0.0         1.0                  N           145           145
# 4            0.0         1.0                  N           145           145
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df8.isnull().sum()
# Out:
# VendorID                 33321
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          33321
# trip_distance                0
# RatecodeID               33321
# store_and_fwd_flag       33321
# PULocationID                 0
# DOLocationID                 0
# payment_type             33321
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# dtype: int64

# %%
df8.dropna(subset = ["VendorID"],inplace= True)
df8.dropna(subset = ["passenger_count"],inplace= True)
df8.dropna(subset = ["RatecodeID"],inplace= True)
df8.dropna(subset = ["store_and_fwd_flag"],inplace= True)
df8.dropna(subset = ["payment_type"],inplace= True)

# %%
df8.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df8.describe().T
# Out:
#                            count        mean         std      min    25%  \
# VendorID               6040036.0    1.644728    0.478881     1.00    1.0
# passenger_count        6040036.0    1.573908    1.213185     0.00    1.0
# trip_distance          6040036.0    3.124045    4.081862     0.00    1.0
# RatecodeID             6040036.0    1.064386    0.789487     1.00    1.0
# PULocationID           6040036.0  161.292200   65.490965     1.00  114.0
# DOLocationID           6040036.0  159.344368   70.151891     1.00  107.0
# payment_type           6040036.0    1.313143    0.492777     1.00    1.0
# fare_amount            6040036.0   13.563707  167.743846 -1856.00    6.5
# extra                  6040036.0    1.152279    1.272700   -21.22    0.0
# mta_tax                6040036.0    0.494252    0.064390    -0.50    0.5
# tip_amount             6040036.0    2.178389    2.964339  -170.00    0.0
# tolls_amount           6040036.0    0.410283    1.913489   -31.62    0.0
# ...

# %%
df8 = df8[df8.fare_amount>=0]
df8 = df8[df8.extra>=0]
df8 = df8[df8.mta_tax>=0]
df8 = df8[df8.tip_amount>=0]
df8 = df8[df8.tolls_amount>=0]
df8 = df8[df8.improvement_surcharge>=0]
df8 = df8[df8.total_amount>=0]
df8.describe().T
# Out:
#                            count        mean         std  min    25%     50%  \
# VendorID               6025234.0    1.643856    0.479144  1.0    1.0    2.00
# passenger_count        6025234.0    1.573908    1.213352  0.0    1.0    1.00
# trip_distance          6025234.0    3.127756    4.082471  0.0    1.0    1.70
# RatecodeID             6025234.0    1.064111    0.789815  1.0    1.0    1.00
# PULocationID           6025234.0  161.294721   65.487214  1.0  114.0  161.00
# DOLocationID           6025234.0  159.338497   70.148905  1.0  107.0  162.00
# payment_type           6025234.0    1.308263    0.482205  1.0    1.0    1.00
# fare_amount            6025234.0   13.627361  167.940776  0.0    6.5    9.50
# extra                  6025234.0    1.156035    1.271600  0.0    0.0    0.50
# mta_tax                6025234.0    0.496665    0.040795  0.0    0.5    0.50
# tip_amount             6025234.0    2.183826    2.964405  0.0    0.0    1.86
# ...

# %%
df9 = pd.read_csv('yellow_tripdata_2019-09.csv')
df10 = pd.read_csv('yellow_tripdata_2019-10.csv')
df11 = pd.read_csv('yellow_tripdata_2019-11.csv')
df12 = pd.read_csv('yellow_tripdata_2019-12.csv')
# Out:
# C:\Users\KritiBhardwaj\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df9.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2019-09-01 00:06:48   2019-09-01 00:25:46              1.0
# 1       1.0  2019-09-01 00:29:17   2019-09-01 00:57:54              1.0
# 2       1.0  2019-09-01 00:41:32   2019-09-01 00:41:36              1.0
# 3       1.0  2019-09-01 00:59:11   2019-09-01 00:59:15              1.0
# 4       1.0  2019-09-01 00:39:41   2019-09-01 00:45:06              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            2.0         1.0                  N           186           161
# 1            5.5         1.0                  N           161           256
# 2            2.9         1.0                  N           145           145
# 3            0.0         1.0                  N           145           145
# 4            1.5         1.0                  N            95            93
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df9.isnull().sum()
# Out:
# VendorID                 34089
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          34089
# trip_distance                0
# RatecodeID               34089
# store_and_fwd_flag       34089
# PULocationID                 0
# DOLocationID                 0
# payment_type             34089
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         1
# dtype: int64

# %%
df9.dropna(subset = ["VendorID"],inplace= True)
df9.dropna(subset = ["passenger_count"],inplace= True)
df9.dropna(subset = ["RatecodeID"],inplace= True)
df9.dropna(subset = ["store_and_fwd_flag"],inplace= True)
df9.dropna(subset = ["payment_type"],inplace= True)
df9.dropna(subset = ["congestion_surcharge"],inplace= True)
df9.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df9.describe().T
# Out:
#                            count        mean        std     min     25%  \
# VendorID               6533698.0    1.648833   0.477360    1.00    1.00
# passenger_count        6533698.0    1.549407   1.192190    0.00    1.00
# trip_distance          6533698.0    3.050830   3.996111    0.00    1.00
# RatecodeID             6533698.0    1.064147   0.840010    1.00    1.00
# PULocationID           6533698.0  163.025205  66.135905    1.00  114.00
# DOLocationID           6533698.0  161.285180  70.446940    1.00  107.00
# payment_type           6533698.0    1.287302   0.480756    1.00    1.00
# fare_amount            6533698.0   13.699369  60.659532 -530.00    6.50
# extra                  6533698.0    1.142374   1.268371   -7.50    0.00
# mta_tax                6533698.0    0.494390   0.063472   -0.50    0.50
# tip_amount             6533698.0    2.289411   2.940493  -80.08    0.00
# tolls_amount           6533698.0    0.399430   1.840281  -40.00    0.00
# ...

# %%
df9 = df9[df9.fare_amount>=0]
df9 = df9[df9.extra>=0]
df9 = df9[df9.mta_tax>=0]
df9 = df9[df9.tip_amount>=0]
df9 = df9[df9.tolls_amount>=0]
df9 = df9[df9.improvement_surcharge>=0]
df9 = df9[df9.total_amount>=0]
df9.describe().T
# Out:
#                            count        mean        std  min    25%     50%  \
# VendorID               6517945.0    1.647985   0.477624  1.0    1.0    2.00
# passenger_count        6517945.0    1.549473   1.192395  0.0    1.0    1.00
# trip_distance          6517945.0    3.054490   3.996869  0.0    1.0    1.68
# RatecodeID             6517945.0    1.063877   0.840439  1.0    1.0    1.00
# PULocationID           6517945.0  163.029345  66.133113  1.0  114.0  162.00
# DOLocationID           6517945.0  161.283186  70.445196  1.0  107.0  162.00
# payment_type           6517945.0    1.282464   0.469895  1.0    1.0    1.00
# fare_amount            6517945.0   13.762461  60.711880  0.0    6.5    9.50
# extra                  6517945.0    1.145992   1.267430  0.0    0.0    0.50
# mta_tax                6517945.0    0.496762   0.040826  0.0    0.5    0.50
# tip_amount             6517945.0    2.294987   2.941208  0.0    0.0    1.96
# ...

# %%
df10.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2019-10-01 00:19:55   2019-10-01 00:23:57              1.0
# 1       1.0  2019-10-01 00:40:19   2019-10-01 00:55:17              2.0
# 2       1.0  2019-10-01 00:06:52   2019-10-01 00:21:23              1.0
# 3       2.0  2019-10-01 00:36:08   2019-10-01 00:36:15              1.0
# 4       2.0  2019-10-01 00:36:08   2019-10-01 00:36:15              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.4         1.0                  N            48           163
# 1            4.3         1.0                  N           144           141
# 2            5.0         1.0                  N           137            80
# 3            0.0         1.0                  N            25            25
# 4            0.0         1.0                  N            25            25
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df10.isnull().sum()
# Out:
# VendorID                 46723
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          46723
# trip_distance                0
# RatecodeID               46723
# store_and_fwd_flag       46723
# PULocationID                 0
# DOLocationID                 0
# payment_type             46723
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# dtype: int64

# %%
df10.dropna(subset = ["VendorID"],inplace= True)
df10.dropna(subset = ["passenger_count"],inplace= True)
df10.dropna(subset = ["RatecodeID"],inplace= True)
df10.dropna(subset = ["store_and_fwd_flag"],inplace= True)
df10.dropna(subset = ["payment_type"],inplace= True)
df10.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df10.describe().T
# Out:
#                            count        mean        std     min     25%  \
# VendorID               7167168.0    1.653885   0.475730    1.00    1.00
# passenger_count        7167168.0    1.538858   1.178510    0.00    1.00
# trip_distance          7167168.0    2.976009   3.893460    0.00    0.99
# RatecodeID             7167168.0    1.062221   0.838042    1.00    1.00
# PULocationID           7167168.0  164.066546  65.636804    1.00  132.00
# DOLocationID           7167168.0  162.155138  69.881614    1.00  113.00
# payment_type           7167168.0    1.282807   0.478468    1.00    1.00
# fare_amount            7167168.0   13.502349  12.315771 -400.00    6.50
# extra                  7167168.0    1.141920   1.267562  -16.62    0.00
# mta_tax                7167168.0    0.494438   0.067463   -0.50    0.50
# tip_amount             7167168.0    2.295663   2.885654 -115.54    0.00
# tolls_amount           7167168.0    0.387570   1.917553  -27.74    0.00
# ...

# %%
df10 = df10[df10.fare_amount>=0]
df10 = df10[df10.extra>=0]
df10 = df10[df10.mta_tax>=0]
df10 = df10[df10.tip_amount>=0]
df10 = df10[df10.tolls_amount>=0]
df10 = df10[df10.improvement_surcharge>=0]
df10 = df10[df10.total_amount>=0]
df10.describe().T
# Out:
#                            count        mean        std  min     25%     50%  \
# VendorID               7149054.0    1.653009   0.476013  1.0    1.00    2.00
# passenger_count        7149054.0    1.538995   1.178860  0.0    1.00    1.00
# trip_distance          7149054.0    2.979734   3.894422  0.0    0.99    1.63
# RatecodeID             7149054.0    1.061932   0.838488  1.0    1.00    1.00
# PULocationID           7149054.0  164.074114  65.633727  1.0  132.00  162.00
# DOLocationID           7149054.0  162.156537  69.881434  1.0  113.00  162.00
# payment_type           7149054.0    1.277770   0.467051  1.0    1.00    1.00
# fare_amount            7149054.0   13.567639  12.231248  0.0    6.50    9.50
# extra                  7149054.0    1.145820   1.266351  0.0    0.00    0.50
# mta_tax                7149054.0    0.496927   0.045189  0.0    0.50    0.50
# tip_amount             7149054.0    2.301584   2.885345  0.0    0.00    1.96
# ...

# %%
df11.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2019-11-01 00:30:41   2019-11-01 00:32:25              1.0
# 1       1.0  2019-11-01 00:34:01   2019-11-01 00:34:09              1.0
# 2       2.0  2019-11-01 00:41:59   2019-11-01 00:42:23              1.0
# 3       2.0  2019-11-01 00:02:39   2019-11-01 00:02:51              1.0
# 4       2.0  2019-11-01 00:18:30   2019-11-01 00:18:39              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N           145           145
# 1            0.0         1.0                  N           145           145
# 2            0.0         1.0                  N           193           193
# 3            0.0         1.0                  N           193           193
# 4            0.0         1.0                  N           226           226
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df11.isnull().sum()
# Out:
# VendorID                 47491
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          47491
# trip_distance                0
# RatecodeID               47491
# store_and_fwd_flag       47491
# PULocationID                 0
# DOLocationID                 0
# payment_type             47491
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         2
# dtype: int64

# %%
df11.dropna(subset = ["VendorID"],inplace= True)
df11.dropna(subset = ["passenger_count"],inplace= True)
df11.dropna(subset = ["RatecodeID"],inplace= True)
df11.dropna(subset = ["store_and_fwd_flag"],inplace= True)
df11.dropna(subset = ["payment_type"],inplace= True)
df11.dropna(subset = ["congestion_surcharge"],inplace= True)
df11.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df11.describe().T
# Out:
#                            count        mean        std     min     25%  \
# VendorID               6830618.0    1.659567   0.473855    1.00    1.00
# passenger_count        6830618.0    1.541835   1.176668    0.00    1.00
# trip_distance          6830618.0    2.906351   3.820487  -21.30    0.97
# RatecodeID             6830618.0    1.060229   0.812700    1.00    1.00
# PULocationID           6830618.0  164.218540  65.708217    1.00  125.00
# DOLocationID           6830618.0  162.286919  69.918026    1.00  113.00
# payment_type           6830618.0    1.281971   0.478808    1.00    1.00
# fare_amount            6830618.0   13.235326  12.116153 -400.00    6.50
# extra                  6830618.0    1.098978   1.254547   -5.00    0.00
# mta_tax                6830618.0    0.494155   0.065109   -0.50    0.50
# tip_amount             6830618.0    2.266496   2.836214  -45.00    0.00
# tolls_amount           6830618.0    0.365261   1.788771  -24.74    0.00
# ...

# %%
df11 = df11[df11.trip_distance>=0]
df11 = df11[df11.fare_amount>=0]
df11 = df11[df11.extra>=0]
df11 = df11[df11.mta_tax>=0]
df11 = df11[df11.tip_amount>=0]
df11 = df11[df11.tolls_amount>=0]
df11 = df11[df11.improvement_surcharge>=0]
df11 = df11[df11.total_amount>=0]
df11.describe().T
# Out:
#                            count        mean        std  min     25%     50%  \
# VendorID               6811841.0    1.658629   0.474170  1.0    1.00    2.00
# passenger_count        6811841.0    1.542002   1.177027  0.0    1.00    1.00
# trip_distance          6811841.0    2.909911   3.821116  0.0    0.97    1.60
# RatecodeID             6811841.0    1.059884   0.813047  1.0    1.00    1.00
# PULocationID           6811841.0  164.225568  65.707364  1.0  125.00  162.00
# DOLocationID           6811841.0  162.289835  69.918348  1.0  113.00  162.00
# payment_type           6811841.0    1.276525   0.466418  1.0    1.00    1.00
# fare_amount            6811841.0   13.305899  12.023327  0.0    6.50    9.50
# extra                  6811841.0    1.102977   1.253590  0.0    0.00    0.50
# mta_tax                6811841.0    0.496857   0.039677  0.0    0.50    0.50
# tip_amount             6811841.0    2.272734   2.837324  0.0    0.00    1.96
# ...

# %%
df12.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2019-12-01 00:26:58   2019-12-01 00:41:45              1.0
# 1       1.0  2019-12-01 00:12:08   2019-12-01 00:12:14              1.0
# 2       1.0  2019-12-01 00:25:53   2019-12-01 00:26:04              1.0
# 3       1.0  2019-12-01 00:12:03   2019-12-01 00:33:19              2.0
# 4       1.0  2019-12-01 00:05:27   2019-12-01 00:16:32              2.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            4.2         1.0                  N           142           116
# 1            0.0         1.0                  N           145           145
# 2            0.0         1.0                  N           145           145
# 3            9.4         1.0                  N           138            25
# 4            1.6         1.0                  N           161           237
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df12.isnull().sum()
# Out:
# VendorID                 51018
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          51018
# trip_distance                0
# RatecodeID               51018
# store_and_fwd_flag       51018
# PULocationID                 0
# DOLocationID                 0
# payment_type             51018
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge         0
# dtype: int64

# %%
df12.dropna(subset = ["VendorID"],inplace= True)
df12.dropna(subset = ["passenger_count"],inplace= True)
df12.dropna(subset = ["RatecodeID"],inplace= True)
df12.dropna(subset = ["store_and_fwd_flag"],inplace= True)
df12.dropna(subset = ["payment_type"],inplace= True)

# %%
df12.isnull().sum()
# Out:
# VendorID                 0
# tpep_pickup_datetime     0
# tpep_dropoff_datetime    0
# passenger_count          0
# trip_distance            0
# RatecodeID               0
# store_and_fwd_flag       0
# PULocationID             0
# DOLocationID             0
# payment_type             0
# fare_amount              0
# extra                    0
# mta_tax                  0
# tip_amount               0
# tolls_amount             0
# improvement_surcharge    0
# total_amount             0
# congestion_surcharge     0
# dtype: int64

# %%
df12 = df12[df12.trip_distance>=0]
df12 = df12[df12.fare_amount>=0]
df12 = df12[df12.extra>=0]
df12 = df12[df12.mta_tax>=0]
df12 = df12[df12.tip_amount>=0]
df12 = df12[df12.tolls_amount>=0]
df12 = df12[df12.improvement_surcharge>=0]
df12 = df12[df12.total_amount>=0]
df12.describe().T
# Out:
#                            count        mean         std  min     25%     50%  \
# VendorID               6824453.0    1.665439    0.471837  1.0    1.00    2.00
# passenger_count        6824453.0    1.551025    1.174692  0.0    1.00    1.00
# trip_distance          6824453.0    2.950667    8.290815  0.0    0.96    1.60
# RatecodeID             6824453.0    1.065401    0.931662  1.0    1.00    1.00
# PULocationID           6824453.0  163.864902   65.950121  1.0  125.00  162.00
# DOLocationID           6824453.0  161.730165   70.251298  1.0  112.00  162.00
# payment_type           6824453.0    1.292938    0.474372  1.0    1.00    1.00
# fare_amount            6824453.0   13.526342  153.044778  0.0    6.50    9.50
# extra                  6824453.0    1.100255    1.252581  0.0    0.00    0.50
# mta_tax                6824453.0    0.496530    0.041803  0.0    0.50    0.50
# tip_amount             6824453.0    2.267752    2.877318  0.0    0.00    1.95
# ...

# %%
df = pd.concat([df1,df2,df3,df4,df5,df5,df6,df7,df8,df9,df10,df11,df12])
