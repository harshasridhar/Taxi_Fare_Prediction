# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-01.csv')
df2=pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-02.csv')
df3=pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-03.csv')
df4=pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-04.csv')
df5=pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-05.csv')
df6=pd.read_csv('https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_2019-06.csv')
df7=pd.read_csv('https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2019-07.csv')
df8=pd.read_csv('https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2019-08.csv')
df9=pd.read_csv('https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2019-09.csv')
df10=pd.read_csv('https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2019-10.csv')
df11=pd.read_csv('https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2019-11.csv')
df12=pd.read_csv('https://nyc-tlc.s3.amazonaws.com/trip+data/green_tripdata_2019-12.csv')

# %%
df1.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-784441b173b6> in <module>()
# ----> 1 df1.describe()
#
# NameError: name 'df1' is not defined

# %%
df1.head()
# Out:
#    VendorID lpep_pickup_datetime  ... trip_type congestion_surcharge
# 0         2  2018-12-21 15:17:29  ...         1                  NaN
# 1         2  2019-01-01 00:10:16  ...         1                  NaN
# 2         2  2019-01-01 00:27:11  ...         1                  NaN
# 3         2  2019-01-01 00:46:20  ...         1                  NaN
# 4         2  2019-01-01 00:19:06  ...         1                  NaN
#
# [5 rows x 20 columns]

# %%
df1.loc[0]
# Out:
# VendorID                                   2
# lpep_pickup_datetime     2018-12-21 15:17:29
# lpep_dropoff_datetime    2018-12-21 15:18:57
# store_and_fwd_flag                         N
# RatecodeID                                 1
# PULocationID                             264
# DOLocationID                             264
# passenger_count                            5
# trip_distance                              0
# fare_amount                                3
# extra                                    0.5
# mta_tax                                  0.5
# tip_amount                                 0
# tolls_amount                               0
# ehail_fee                                NaN
# improvement_surcharge                    0.3
# total_amount                             4.3
# payment_type                               2
# trip_type                                  1
# congestion_surcharge                     NaN
# Name: 0, dtype: object

# %%
df1.drop(0,inplace=True)     ###to remove the 1 cell

# %%
import seaborn as sns

# %%
sns.countplot(x='store_and_fwd_flag',data=df1)

# %%
df2.head()
# Out:
#    VendorID lpep_pickup_datetime  ... trip_type congestion_surcharge
# 0         2  2019-02-01 00:10:19  ...         1                  0.0
# 1         2  2019-02-01 00:02:16  ...         1                  0.0
# 2         2  2019-02-01 00:37:19  ...         1                  0.0
# 3         1  2019-02-01 00:10:10  ...         1                  0.0
# 4         1  2019-02-01 00:30:19  ...         1                  0.0
#
# [5 rows x 20 columns]

# %%
sns.countplot(x='store_and_fwd_flag',data=df2)

# %%
sns.countplot(x='RatecodeID',data=df2)

# %%
sns.countplot(x='passenger_count',data=df2)

# %%
sns.countplot(x='payment_type',data=df2)

# %%
print(f'shape of data: {df1.shape},{df2.shape},{df3.shape},{df4.shape},{df5.shape},{df6.shape},{df7.shape},{df8.shape},{df9.shape},{df10.shape},{df11.shape},{df12.shape}')
# Out:
# shape of data: (630917, 20),(575685, 20),(601102, 20),(514392, 20),(504887, 20),(471052, 20),(470743, 20),(449695, 20),(449063, 20),(476386, 20),(449500, 20),(450627, 20)

# %%
print(f'null values in data: {df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12.isnull().sum().sum()}')
# Out:
# null values in data: (        VendorID lpep_pickup_datetime  ... trip_type congestion_surcharge
# 1              2  2019-01-01 00:10:16  ...         1                  NaN
# 2              2  2019-01-01 00:27:11  ...         1                  NaN
# 3              2  2019-01-01 00:46:20  ...         1                  NaN
# 4              2  2019-01-01 00:19:06  ...         1                  NaN
# 5              2  2019-01-01 00:12:35  ...         1                  NaN
# ...          ...                  ...  ...       ...                  ...
# 630913         2  2019-01-31 23:08:27  ...         1                  0.0
# 630914         2  2019-01-31 23:21:26  ...         1                  0.0
# 630915         2  2019-01-31 23:30:05  ...         1                  0.0
# 630916         2  2019-01-31 23:59:58  ...         1                  0.0
# 630917         2  2019-01-31 23:18:22  ...         1                  0.0
#
# ...

# %%
df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12.describe().T
# Out:
# (        VendorID lpep_pickup_datetime  ... trip_type congestion_surcharge
#  1              2  2019-01-01 00:10:16  ...         1                  NaN
#  2              2  2019-01-01 00:27:11  ...         1                  NaN
#  3              2  2019-01-01 00:46:20  ...         1                  NaN
#  4              2  2019-01-01 00:19:06  ...         1                  NaN
#  5              2  2019-01-01 00:12:35  ...         1                  NaN
#  ...          ...                  ...  ...       ...                  ...
#  630913         2  2019-01-31 23:08:27  ...         1                  0.0
#  630914         2  2019-01-31 23:21:26  ...         1                  0.0
#  630915         2  2019-01-31 23:30:05  ...         1                  0.0
#  630916         2  2019-01-31 23:59:58  ...         1                  0.0
#  630917         2  2019-01-31 23:18:22  ...         1                  0.0
#
#  [630917 rows x 20 columns],
# ...

# %%
combine=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12],ignore_index=False)

# %%
combine.boxplot()

# %%
combine[['trip_distance','passenger_count']].boxplot()

# %%
combine.describe()
# Out:
#            VendorID    RatecodeID  ...     trip_type  congestion_surcharge
# count  5.629942e+06  5.629942e+06  ...  5.629583e+06          5.083561e+06
# mean   1.841199e+00  1.186886e+00  ...  1.044463e+00          3.986029e-01
# std    3.654905e-01  8.865917e-01  ...  2.061218e-01          9.679345e-01
# min    1.000000e+00  1.000000e+00  ...  1.000000e+00         -2.750000e+00
# 25%    2.000000e+00  1.000000e+00  ...  1.000000e+00          0.000000e+00
# 50%    2.000000e+00  1.000000e+00  ...  1.000000e+00          0.000000e+00
# 75%    2.000000e+00  1.000000e+00  ...  1.000000e+00          0.000000e+00
# max    2.000000e+00  9.900000e+01  ...  2.000000e+00          2.750000e+00
#
# [8 rows x 17 columns]

# %%
combine = combine[combine.trip_distance>=0]

# %%
combine.describe()
# Out:
#            VendorID    RatecodeID  ...     trip_type  congestion_surcharge
# count  5.629890e+06  5.629890e+06  ...  5.629531e+06          5.083509e+06
# mean   1.841197e+00  1.186850e+00  ...  1.044464e+00          3.986065e-01
# std    3.654919e-01  8.865201e-01  ...  2.061227e-01          9.679381e-01
# min    1.000000e+00  1.000000e+00  ...  1.000000e+00         -2.750000e+00
# 25%    2.000000e+00  1.000000e+00  ...  1.000000e+00          0.000000e+00
# 50%    2.000000e+00  1.000000e+00  ...  1.000000e+00          0.000000e+00
# 75%    2.000000e+00  1.000000e+00  ...  1.000000e+00          0.000000e+00
# max    2.000000e+00  9.900000e+01  ...  2.000000e+00          2.750000e+00
#
# [8 rows x 17 columns]

# %%
combine[['trip_distance',]].boxplot()

# %%
g=sns.heatmap(combine.corr(),annot=True,cmap="RdYlGn")

# %%
df1'=pd.read_csv(' https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv')
df2'=pd.read_csv(' https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-02.csv')
df3'=pd.read_csv(' https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-03.csv')
df4'=pd.read_csv(' https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-04.csv')
df5'=pd.read_csv(' https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-05.csv')
df6'=pd.read_csv(' https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-06.csv')
# Out:
#   File "<ipython-input-4-55fa68907289>", line 1
#     df1'=pd.read_csv(' https://s3.amazonaws.com/nyc-tlc/trip+data/yellow_tripdata_2019-01.csv')
#                      ^
# SyntaxError: invalid syntax
